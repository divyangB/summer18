# %%
import numpy as np
import matplotlib.pyplot as plt
data= np.loadtxt('file1.txt',dtype='int64',delimiter=' ')
data2= np.loadtxt('file2.txt',dtype='int64',delimiter=' ')
print(data1)
print(data2)

plt.plot(data,data2,label="random data")
plt.bar(data,data2)
plt.legend()

plt.show()
# Out:
# [ 2  3  4  5 65  5  6  7  7  8 89  9  9  0  0  2  3  4  5  6  7  8  9  9
#   7  5  4  3  3  5  7  8  9  6  5  4  3  4  4  5  6  7  8  8]
# [ 2  3  4  6  6  7  8  9  8  4 53 45 87  9  0 89  0  9 76 76  7 64  5  3
#   4 32  4 43 55  4  3 43 35 35 43 54  2  4  3  5 35 35 43 54]
